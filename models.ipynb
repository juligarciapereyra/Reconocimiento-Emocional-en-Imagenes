# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install torchinfo
# !pip install torchmetrics

# %%
# !pip install torch torchvision captum matplotlib==3.3.4 Flask-Compress

# %%
from Configs import *
from DataSet import *
from Main import main
from Models import *
import torch.optim as optim

# %%
dataset_config = DatasetConfig()
train_config = TrainingConfig()

# %%
CKPT_DIR = create_checkpoint_dir(TrainingConfig.CHECKPOINT_DIR)
Model_Dir = create_checkpoint_dir(TrainingConfig.MODEL_DIR)

model = get_vgg(num_classes=dataset_config.NUM_CLASSES)
model = model.float().to(DEVICE)

optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
# Out:
# Checkpoint directory: CKPT_inter
# Checkpoint directory: MODEL_DIR

# %%
history = main(
    emotion_mapping,
    DEVICE,
    model = model,
    optimizer = optimizer,
    ckpt_dir = CKPT_DIR,
    data_config = dataset_config,
    train_config = train_config,
    path_dataset = PATH,
    model_dir = Model_Dir,
    model_name='VGG'
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
